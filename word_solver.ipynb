# %%
import random
import math
from nltk.corpus import wordnet

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
# from nltk.corpus import wordnet
# def meaningful(words):
#     words_with_meanings = []
#     for word in words:
#         word = str(word).lower()  # Ensure the word is a string and convert to lowercase
#         synsets = wordnet.synsets(word)
#         if synsets:
#             words_with_meanings.append((word, synsets[0].definition()))
#     return words_with_meanings

# print(meaningful(['giant']))
# Out:
# [('giant', 'any creature of exceptional size')]

# %%
def meaningful(words):
    words_with_meanings = []
    for word in words:
        word = str(word).lower()  # Ensure the word is a string and convert to lowercase
        synsets = wordnet.synsets(word)
        if synsets:
            words_with_meanings.append(word)
    return words_with_meanings

# print(meaningful(['dog', 'cat', 'mmmmm']))
# Out:
# ['dog', 'cat']

# %%
word = input('Insert word: ')
word_list = list(word)
number_length = int(input('Insert length: '))
count = math.factorial(number_length)

# %%
storage = set()
t = 0

for i in range(0, 200000):
    x = random.sample(word_list, number_length)
    x = ''.join(x)
    print(x)
    storage.add(x)
    t += 1

    if t == 200000:
        break
# Out:
# sea
# vae
# aev
# sve
# vse
# sae
# esa
# eav
# esa
# sea
# vas
# ave
# aev
# sev
# vse
# ves
# eas
# vse
# ves
# vae
# vea
# vas
# ves
# esa
# asv
# eva
# ves
# ave
# aes
# sea
# vas
# ase
# vae
# vas
# eav
# aes
# sve
# sae
# sve
# esa
# vse
# vae
# vae
# asv
# ves
# sev
# sae
# vae
# ase
# sva
# sae
# avs
# vea
# vsa
# esv
# sae
# esa
# esa
# sve
# vsa
# asv
# eas
# ase
# aev
# vse
# ves
# ave
# eva
# esa
# esa
# eav
# eva
# sae
# eas
# vse
# sav
# avs
# asv
# sev
# esv
# vea
# vae
# vse
# sva
# ves
# sea
# aev
# ase
# vea
# sva
# asv
# esa
# esa
# vse
# sae
# esa
# avs
# asv
# aes
# esv
# ves
# aes
# vea
# avs
# aes
# vea
# sva
# eav
# vsa
# eav
# vae
# esv
# eav
# sea
# vsa
# sav
# asv
# ves
# vas
# avs
# vea
# aev
# sev
# vea
# esv
# vsa
# vsa
# eva
# esv
# evs
# sve
# eav
# eas
# vsa
# ves
# vea
# sev
# vse
# evs
# aes
# esa
# aev
# avs
# vea
# aev
# esa
# sev
# sav
# vas
# ase
# sae
# sev
# evs
# vsa
# eva
# avs
# sve
# vea
# sae
# eas
# ave
# asv
# eas
# aes
# avs
# eva
# ...

# %%
print('')
print('Iteration:', t)
print('Number of elements in the set:', len(storage))
print('Difference:', t - len(storage))
# Out:
# Iteration: 200000
# Number of elements in the set: 24
# Difference: 199976

# %%
wordx = list(storage)
words_with_meaning = meaningful(wordx)
print('Words with meaning:', words_with_meaning)
# Out:
# Words with meaning: ['sea', 'eas', 'vas', 'avs', 'ves', 'evs']
